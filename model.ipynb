# %% [markdown]
# <a href="https://colab.research.google.com/github/Ru1chi/sample/blob/main/model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import pickle
import seaborn as sns

# %%
# Load the dataset
df = pd.read_excel('/content/recipees.xlsx')



df
# Out:
#                recipe_name                          ingredients  calories  \
# 0             Caesar Salad  Romaine Lettuce, Croutons, Parmesan       180
# 1          Margarita Pizza      Dough, Tomato Sauce, Mozzarella       300
# 2        Vegetable Lasagna      Zucchini, Tomato Sauce, Ricotta       350
# 3        BBQ Chicken Wings           Chicken, BBQ Sauce, Spices       400
# 4           Fruit Smoothie           Banana, Strawberry, Yogurt       150
# ..                     ...                                  ...       ...
# 95            Mango Sorbet                  Mango, Sugar, Water       150
# 96  Peanut Butter Sandwich          Peanut Butter, Bread, Honey       300
# 97              Tofu Salad                Tofu, Lettuce, Tomato       200
# 98          Grilled Shrimp             Shrimp, Olive Oil, Lemon       200
# 99              Fruit Tart              Flour, Custard, Berries       300
#
#     protein  carbs  fat  price($)
# 0         7      8   12       4.5
# ...

# %%
df.describe()

df.shape
# Out:
# (100, 7)

# %%
sns.pairplot(df[['calories', 'protein', 'carbs', 'fat', 'price($)']])

# %%
import numpy as np

#Correlation Matrix
sns.heatmap(df[['calories', 'protein', 'carbs', 'fat', 'price($)','category']].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Features for clustering
X = df[['calories', 'protein', 'carbs', 'fat', 'price($)']]



X.shape
# Out:
# (100, 5)

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.97670588, -0.74294932, -1.31262359, -0.03024117, -0.30374665],
#        [ 0.29449483,  0.13239598,  0.86149416, -0.34856927,  1.05053778],
#        [ 0.82416179,  0.67948679,  1.20120005,  0.44725098,  0.47013017],
#        [ 1.35382875,  1.2265776 , -1.17674123,  1.24307123,  1.43747618],
#        [-1.29450605, -1.07120381,  0.18208236, -1.62188167, -0.88415426],
#        [ 0.29449483,  0.67948679, -0.15762354, -0.34856927,  0.85706857],
#        [-0.76483909, -0.96178565, -0.49732943, -0.34856927, -0.49721585],
#        [ 1.35382875, -0.96178565,  2.22031775,  1.24307123, -1.07762346],
#        [ 1.88349571,  1.77366842,  0.86149416,  1.24307123,  1.82441459],
#        [-0.76483909, -0.96178565, -1.17674123,  0.44725098, -0.11027745],
#        [ 0.29449483, -0.41469484,  1.54090595, -0.34856927,  0.27666096],
#        [ 0.82416179,  1.77366842, -1.51644713,  1.24307123,  1.05053778],
#        [ 1.35382875,  0.67948679, -0.15762354,  1.24307123,  0.66359937],
# ...

# %%
# Train a K-Means model
n_clusters = 4  # Number of clusters can be adjusted
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(X_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
df['Cluster'] = kmeans.labels_

# %%
# Calculate the silhouette score
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(X_scaled, df['Cluster'])
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.2991371658606721

# %%
# Save the model and scaler to .sav files
with open('kmeans_model11.sav', 'wb') as model_file:
    pickle.dump(kmeans, model_file)
with open('scaler_model11.sav', 'wb') as scaler_file:
    pickle.dump(scaler, scaler_file)

print("Model and scaler saved successfully.")
# Out:
# Model and scaler saved successfully.

# %% [markdown]
# ### **Extra**

# %% [markdown]
# ### **Hierarchical Clustering**

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt

# Perform hierarchical clustering
Z = linkage(X_scaled, method='ward')
plt.figure(figsize=(10, 7))
dendrogram(Z)
plt.show()

# Get cluster labels
cluster_labels = fcluster(Z, n_clusters, criterion='maxclust')

# %%
#Silhouette Score for heirarchical clustering
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(X_scaled, cluster_labels)
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.27349943077714955

# %% [markdown]
# ### **3. Model Comparison with Target**

# %% [markdown]
# ### **DBSCAN**

# %%
from sklearn.cluster import DBSCAN

# Apply DBSCAN clustering
dbscan = DBSCAN(eps=0.5, min_samples=2)
dbscan.fit(X_scaled)
df['Cluster'] = dbscan.labels_
